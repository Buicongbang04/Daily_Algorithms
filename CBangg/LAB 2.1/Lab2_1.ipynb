# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Step 1: Load the dataset
df = pd.read_csv("sales_data_new.csv")

# %%
# Step 2: Data Exploration
# View the first few rows of the dataset
print("First few rows of the dataset:")
print(df.head())
# Out:
# First few rows of the dataset:
#      Product  Amount        Date
# 0  Product A   100.0  01/01/2023
# 1  Product B   150.0  02/01/2023
# 2  Product A    75.0  03/01/2023
# 3  Product C   200.0  04/01/2023
# 4  Product B   120.0  05/01/2023

# %%
# Check for missing data
print("\nMissing data summary:")
print(df.isnull().sum())
# Out:
# Missing data summary:
# Product     0
# Amount     17
# Date        0
# dtype: int64

# %%
### Fill missing values with mean for  ###
df['Amount'].fillna(df['Amount'].mean(), inplace=True)

# %%
# Summary statistics
print("\nSummary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#            Amount
# count  253.000000
# mean   141.440678
# std     50.462550
# min     75.000000
# 25%     95.000000
# 50%    140.000000
# 75%    190.000000
# max    230.000000

# %%
# Filter the data for a specific product (e.g., Product A)
product_a_data = df[df["Product"] == "Product A"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Product  253 non-null    object
#  1   Amount   253 non-null    float64
#  2   Date     253 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 6.1+ KB

# %%
# Step 3: Basic Data Visualization
# Create a bar chart for product sales
product_sales = df.groupby("Product")["Amount"].sum()
product_sales.plot(kind="bar", title="Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()

# %%
# Create a line chart for daily sales
df["Date"] = pd.to_datetime(df["Date"], format='%d/%m/%Y')
daily_sales = df.groupby("Date")["Amount"].sum()
daily_sales.plot(kind="line", title="Daily Sales")
plt.xlabel("Date")
plt.ylabel("Sales Amount")
plt.show()

# %%
# Create a scatter plot for product sales by date
plt.scatter(df["Date"], df["Amount"])
plt.title("Product Sales by Date")
plt.xlabel("Date")
plt.ylabel("Sales Amount")
plt.xticks(rotation=45)
plt.show()
