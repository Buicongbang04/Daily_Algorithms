# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("dbscan_outlier_demo.csv")
df.head()
# Out:
#     Feature1   Feature2
# 0  52.483571  49.308678
# 1  53.238443  57.615149
# 2  48.829233  48.829315
# 3  57.896064  53.837174
# 4  47.652628  52.712800

# %%
dbscan = DBSCAN(eps=3, min_samples=5)
df['Cluster'] = dbscan.fit_predict(df[['Feature1', 'Feature2']])

# %%
outliers = df[df['Cluster'] == -1]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Feature1'], df['Feature2'], s=20, label='Normal')
plt.scatter(outliers['Feature1'], outliers['Feature2'], s=20, label='Outliers')
plt.xlabel('Feature1')
plt.ylabel('Feature2')
plt.title('Outlier Detection using DBSCAN')
plt.grid(True)
plt.legend()
plt.show()

# %%
print(f"Danh sách các outlier:")
outliers = pd.DataFrame(df[df['Cluster'] == -1][['Feature1', 'Feature2']])
outliers
# Out:
# Danh sách các outlier:
#       Feature1   Feature2
# 104  52.575238  69.263657
# 110  61.573293  40.663674
# 131  33.793663  44.878062
# 142  60.665167  40.239561
# 239  65.394404  55.597875
# 323  36.515567  49.728526
# 530  53.858494  35.757287
# 550  54.990051  35.518723
# 580  37.502971  61.454713
# 769  44.150416  35.638689
# 795  44.639305  35.393248
# 950  11.613896  95.591883
# 951  31.396672  88.840367
# 952  60.294288  82.670736
# 953  98.401316  28.840544
# 954  96.113549  38.948189
# 955  38.551190  34.038710
# 956  54.140761  15.414504
# 958  76.190181  83.364996
# 959  44.044135  30.233325
# 960  25.933490  19.462384
# 961   5.764758  34.244798
# 962  27.024769  96.641739
# 963  55.770883  34.727704
# 964  58.046760  13.919670
# 967  99.384839  88.031476
# 969  62.066048  20.131211
# 970  39.513774   3.945953
# 972  22.774974  96.402885
# 973  90.945461  72.214324
# 974  53.338663  86.996916
# 975  13.065234  79.050979
# 976  12.482081  79.421066
# ...
